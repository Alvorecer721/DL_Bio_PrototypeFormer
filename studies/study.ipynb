# %%
import pickle
import optuna

# %%
with open("tabula_muris_studies.pkl", 'rb') as f:
    tabula_mruis_studies = pickle.load(f)

# %%
import matplotlib.pyplot as plt

optuna.visualization.matplotlib.plot_parallel_coordinate(tabula_mruis_studies, 
                                                         params=[
                                                             "lr", 
                                                             "weight_decay", 
                                                             "n_sub_support",  
                                                             "n_layer", 
                                                             "n_head", 
                                                             "contrastive_coef", 
                                                             "dropout", 
                                                             "norm_first", 
                                                             "contrastive_loss", 
                                                             "ffn_dim"
                                                             ])
plt.tight_layout()
# Out:
# /var/folders/n3/gbdx6wws5kb_m82h5gt5pf440000gn/T/ipykernel_21874/3723361591.py:3: ExperimentalWarning: plot_parallel_coordinate is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_parallel_coordinate(tabula_mruis_studies,
